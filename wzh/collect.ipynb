# %%
import os
print(os.getcwd())
# Out:
# c:\desktop\YiBao\wzh

# %%
import os
print(os.listdir(os.getcwd()))
# Out:
# ['collect.ipynb', 'collect.py', 'collected.json', 'invoice.json', 'packing_list.json', 'README.md']
